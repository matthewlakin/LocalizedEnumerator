# %%
from paper_examples import process_input, mkEnumeratorGeometric

def doSimpleTest(interTetherDistanceNanoMeters, seed=42):
    domainLengthStr = 'longDomain spcr length 5 longDomain x length 30'
    s = f'( [[ < tether(0,0) spcr x> | <tether({interTetherDistanceNanoMeters},0) spcr x*> ]] )'
    crn = process_input(s, domainLengthStr, mkEnumeratorGeometric(seed), verbose=False)
    crn.displayRepresentation()

# %%
print('FIRST TEST (should find 1 reaction)')
doSimpleTest(10)
# Out:
# FIRST TEST (should find 1 reaction)
# REACTIONS:
# REACTION 1: sp_0 ->{0.003} sp_1
#
# KEY TO SPECIES:
# sp_0:
# sp_1:

# %%
print('SECOND TEST (should find no reactions)')
doSimpleTest(20)
# Out:
# SECOND TEST (should find no reactions)
# REACTIONS:
# None
#
# KEY TO SPECIES:
# sp_0:
